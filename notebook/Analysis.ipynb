# %%
from pathlib import Path
import grade_focused_analysis as gfa

print(f"cwd: {Path.cwd()}")
print(f"resolved_project_root: {gfa._resolve_project_root()}")
# Out:
# cwd: c:\Users\User\Downloads\extract-csv\notebook
# resolved_project_root: C:\Users\User\Downloads\extract-csv

# %%
import importlib
import grade_focused_analysis as gfa

importlib.reload(gfa)

dfs = gfa.build_grade_dataframes()
bopf_df = dfs["bopf_df"]
fbop_df = dfs["fbop_df"]
op1_df = dfs["op1_df"]
grade_summary_df = dfs["grade_summary_df"]

dfs
# Out:
# {'sales_base':         sale_id  sale_number  sale_year sale_month  total_kgs  \
#  0  SALE_06_2026            6       2026   February    5949847
#  1  SALE_10_2026           10       2026      March    5153656
#  2  SALE_02_2026            2       2026    January    5554655
#  3  SALE_07_2026            7       2026   February    5723014
#  4  SALE_05_2026            5       2026   February    6089722
#  5  SALE_03_2026            3       2026    January    6349608
#  6  SALE_08_2026            8       2026   February    5533190
#  7  SALE_04_2026            4       2026    January    6024398
#  8  SALE_09_2026            9       2026      March    5301543
#  9  SALE_01_2026            1       2026    January    5794884
#
#     sentiment_overall  total_sold_weekly_2026  total_sold_weekly_2025  \
#  0             0.3778                 5106861                 5480943
#  1             0.3143                 4293469                 4992963
# ...

# %%
bopf_df[bopf_df["sale_id"] == "SALE_10_2026"]
# Out:
#          sale_id   elevation       segment grade  price_lo_lkr  price_hi_lkr  \
# 13  SALE_10_2026  high_grown      best_uva  bopf        1240.0        1280.0
# 22  SALE_10_2026  high_grown  best_western  bopf        1380.0        1650.0
#
#     sale_number  sale_year sale_month  total_kgs  ...  \
# 13           10       2026      March    5153656  ...
# 22           10       2026      March    5153656  ...
#
#     gross_lkr_weekly_ctc_medium_2026  gross_lkr_weekly_orthodox_low_2026  \
# 13                               NaN                                 NaN
# 22                               NaN                                 NaN
#
#     sold_to_offered_ratio  yoy_volume_change_pct  demand_bopf  demand_fbop  \
# 13               0.833092             -14.009597          3.5          3.0
# 22               0.833092             -14.009597          3.5          3.0
#
#     demand_op1  price_mid_lkr  price_range_lkr  wow_price_mid_change
# ...
